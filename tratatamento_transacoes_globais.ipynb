# %%
import pandas as pd

# %%
#Aqui eu tô lendo o arquivo csv e armazenando em variável
df_transacoes = pd.read_csv('data/transactions_data.csv')

# %%
df_usuarios = pd.read_csv('data/users_data.csv')

# %%
df_cartoes = pd.read_csv('data/cards_data.csv')

# %%
df_transacoes
# Out:
#                 id                 date  client_id  card_id   amount  \
# 0          7475327  2010-01-01 00:01:00       1556     2972  $-77.00
# 1          7475328  2010-01-01 00:02:00        561     4575   $14.57
# 2          7475329  2010-01-01 00:02:00       1129      102   $80.00
# 3          7475331  2010-01-01 00:05:00        430     2860  $200.00
# 4          7475332  2010-01-01 00:06:00        848     3915   $46.41
# ...            ...                  ...        ...      ...      ...
# 13305910  23761868  2019-10-31 23:56:00       1718     2379    $1.11
# 13305911  23761869  2019-10-31 23:56:00       1766     2066   $12.80
# 13305912  23761870  2019-10-31 23:57:00        199     1031   $40.44
# 13305913  23761873  2019-10-31 23:58:00       1986     5443    $4.00
# 13305914  23761874  2019-10-31 23:59:00        489     5697   $12.88
#
#                     use_chip  merchant_id merchant_city merchant_state  \
# ...

# %%
df_usuarios
# Out:
#         id  current_age  retirement_age  birth_year  birth_month  gender  \
# 0      825           53              66        1966           11  Female
# 1     1746           53              68        1966           12  Female
# 2     1718           81              67        1938           11  Female
# 3      708           63              63        1957            1  Female
# 4     1164           43              70        1976            9    Male
# ...    ...          ...             ...         ...          ...     ...
# 1995   986           32              70        1987            7    Male
# 1996  1944           62              65        1957           11  Female
# 1997   185           47              67        1973            1  Female
# 1998  1007           66              60        1954            2    Male
# 1999  1110           21              60        1998           11  Female
#
#                        address  latitude  longitude per_capita_income  \
# ...

# %%
df_cartoes
# Out:
#         id  client_id  card_brand        card_type       card_number  expires  \
# 0     4524        825        Visa            Debit  4344676511950444  12/2022
# 1     2731        825        Visa            Debit  4956965974959986  12/2020
# 2     3701        825        Visa            Debit  4582313478255491  02/2024
# 3       42        825        Visa           Credit  4879494103069057  08/2024
# 4     4659        825  Mastercard  Debit (Prepaid)  5722874738736011  03/2009
# ...    ...        ...         ...              ...               ...      ...
# 6141  5361        185        Amex           Credit   300609782832003  01/2024
# 6142  2711        185        Visa           Credit  4718517475996018  01/2021
# 6143  1305       1007  Mastercard           Credit  5929512204765914  08/2020
# 6144   743       1110  Mastercard            Debit  5589768928167462  01/2020
# 6145  3199       1110        Visa           Credit  4994011318343994  12/2020
#
# ...

# %%
#Esse método info() mostra informações sobre o dataframe quantidade de memória, tipo de dado de cada coluna
df_transacoes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13305915 entries, 0 to 13305914
# Data columns (total 12 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   id              int64
#  1   date            object
#  2   client_id       int64
#  3   card_id         int64
#  4   amount          object
#  5   use_chip        object
#  6   merchant_id     int64
#  7   merchant_city   object
#  8   merchant_state  object
#  9   zip             float64
#  10  mcc             int64
#  11  errors          object
# dtypes: float64(1), int64(5), object(6)
# memory usage: 1.2+ GB

# %%
#TRATAMENTO DF_TRANSACOES TIRANDO CIFRÃO E CONVERTENDO PARA FLOAT
df_transacoes['amount'] = df_transacoes['amount'].str.replace('$', '').astype(float)
df_transacoes

# %%
df_cartoes['credit_limit'] = df_cartoes['credit_limit'].str.replace('$', '').astype(float)
df_cartoes

# %%
df_usuarios['per_capita_income'] = df_usuarios['per_capit_income'].str.replace('$', '').astype(float)

# %%
df_usuarios['total_debt'] = df_usuarios['total_debt'].str.replace('$', '').astype(float);

# %%
df_usuarios['yearly_income'] = df_usuarios['yearly_income'].str.replace('$', '').astype(float);

# %%
df_usuarios
# Out:
#         id  current_age  retirement_age  birth_year  birth_month  gender  \
# 0      825           53              66        1966           11  Female
# 1     1746           53              68        1966           12  Female
# 2     1718           81              67        1938           11  Female
# 3      708           63              63        1957            1  Female
# 4     1164           43              70        1976            9    Male
# ...    ...          ...             ...         ...          ...     ...
# 1995   986           32              70        1987            7    Male
# 1996  1944           62              65        1957           11  Female
# 1997   185           47              67        1973            1  Female
# 1998  1007           66              60        1954            2    Male
# 1999  1110           21              60        1998           11  Female
#
#                        address  latitude  longitude  per_capita_income  \
# ...

# %%
df_usuarios.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 2000 non-null   int64
#  1   current_age        2000 non-null   int64
#  2   retirement_age     2000 non-null   int64
#  3   birth_year         2000 non-null   int64
#  4   birth_month        2000 non-null   int64
#  5   gender             2000 non-null   object
#  6   address            2000 non-null   object
#  7   latitude           2000 non-null   float64
#  8   longitude          2000 non-null   float64
#  9   per_capita_income  2000 non-null   object
#  10  yearly_income      2000 non-null   object
#  11  total_debt         2000 non-null   object
#  12  credit_score       2000 non-null   int64
#  13  num_credit_cards   2000 non-null   int64
# dtypes: float64(2), int64(7), object(5)
# memory usage: 218.9+ KB

# %%
df_transacoes
# Out:
#                 id                 date  client_id  card_id  amount  \
# 0          7475327  2010-01-01 00:01:00       1556     2972  -77.00
# 1          7475328  2010-01-01 00:02:00        561     4575   14.57
# 2          7475329  2010-01-01 00:02:00       1129      102   80.00
# 3          7475331  2010-01-01 00:05:00        430     2860  200.00
# 4          7475332  2010-01-01 00:06:00        848     3915   46.41
# ...            ...                  ...        ...      ...     ...
# 13305910  23761868  2019-10-31 23:56:00       1718     2379    1.11
# 13305911  23761869  2019-10-31 23:56:00       1766     2066   12.80
# 13305912  23761870  2019-10-31 23:57:00        199     1031   40.44
# 13305913  23761873  2019-10-31 23:58:00       1986     5443    4.00
# 13305914  23761874  2019-10-31 23:59:00        489     5697   12.88
#
#                     use_chip  merchant_id merchant_city merchant_state  \
# 0          Swipe Transaction        59935        Beulah             ND
# ...

# %%
df_transacoes.describe()
# Out:
#                  id     client_id       card_id        amount   merchant_id  \
# count  1.330592e+07  1.330592e+07  1.330592e+07  1.330592e+07  1.330592e+07
# mean   1.558402e+07  1.026812e+03  3.475268e+03  4.297604e+01  4.772376e+04
# std    4.704499e+06  5.816386e+02  1.674356e+03  8.165575e+01  2.581534e+04
# min    7.475327e+06  0.000000e+00  0.000000e+00 -5.000000e+02  1.000000e+00
# 25%    1.150604e+07  5.190000e+02  2.413000e+03  8.930000e+00  2.588700e+04
# 50%    1.557087e+07  1.070000e+03  3.584000e+03  2.899000e+01  4.592600e+04
# 75%    1.965361e+07  1.531000e+03  4.901000e+03  6.371000e+01  6.757000e+04
# max    2.376187e+07  1.998000e+03  6.144000e+03  6.820200e+03  1.003420e+05
#
#                 zip           mcc
# count  1.165321e+07  1.330592e+07
# mean   5.132782e+04  5.565440e+03
# std    2.940423e+04  8.757002e+02
# min    1.001000e+03  1.711000e+03
# 25%    2.860200e+04  5.300000e+03
# 50%    4.767000e+04  5.499000e+03
# 75%    7.790100e+04  5.812000e+03
# ...

# %%
#Vendo os valores nulos de cada coluna
df_transacoes.isnull().sum()
# Out:
# id                       0
# date                     0
# client_id                0
# card_id                  0
# amount                   0
# use_chip                 0
# merchant_id              0
# merchant_city            0
# merchant_state     1563700
# zip                1652706
# mcc                      0
# errors            13094522
# dtype: int64

# %%
df_transacoes_cidade_estado_zip = df_transacoes[['merchant_city', 'merchant_state', 'zip']]
df_transacoes_cidade_estado_zip
# Out:
#          merchant_city merchant_state      zip
# 0               Beulah             ND  58523.0
# 1           Bettendorf             IA  52722.0
# 2                Vista             CA  92084.0
# 3          Crown Point             IN  46307.0
# 4              Harwood             MD  20776.0
# ...                ...            ...      ...
# 13305910   West Covina             CA  91792.0
# 13305911        ONLINE            NaN      NaN
# 13305912         Allen             TX  75002.0
# 13305913     Daly City             CA  94014.0
# 13305914    Greenbrier             TN  37073.0
#
# [13305915 rows x 3 columns]

# %%
df_transacoes_cidade_estado_zip[df_transacoes_cidade_estado_zip['merchant_city'] == 'ONLINE']
# Out:
#          merchant_city merchant_state  zip
# 7               ONLINE            NaN  NaN
# 8               ONLINE            NaN  NaN
# 18              ONLINE            NaN  NaN
# 24              ONLINE            NaN  NaN
# 26              ONLINE            NaN  NaN
# ...                ...            ...  ...
# 13305879        ONLINE            NaN  NaN
# 13305880        ONLINE            NaN  NaN
# 13305888        ONLINE            NaN  NaN
# 13305897        ONLINE            NaN  NaN
# 13305911        ONLINE            NaN  NaN
#
# [1563700 rows x 3 columns]
